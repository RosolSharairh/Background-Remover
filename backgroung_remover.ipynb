# %% [markdown]
# # **Background Remover**

# %% [markdown]
# **Original photo**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install rembg[gpu]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rembg[gpu]
#   Downloading rembg-2.0.30-py3-none-any.whl (13 kB)
# Collecting opencv-python-headless~=4.6.0.66
#   Downloading opencv_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (48.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 MB 14.9 MB/s eta 0:00:00
# Collecting tqdm~=4.64.1
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 4.4 MB/s eta 0:00:00
# Collecting scipy~=1.9.3
#   Downloading scipy-1.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 8.4 MB/s eta 0:00:00
# Collecting aiohttp~=3.8.1
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: pooch~=1.6.0 in /usr/local/lib/python3.9/dist-packages (from rembg[gpu]) (1.6.0)
# Collecting uvicorn~=0.20.0
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 KB 3.6 MB/s eta 0:00:00
# Collecting python-multipart~=0.0.5
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image~=0.19.3 in /usr/local/lib/python3.9/dist-packages (from rembg[gpu]) (0.19.3)
# Collecting filetype~=1.2.0
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting watchdog~=2.1.9
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 4.7 MB/s eta 0:00:00
# Collecting asyncer~=0.0.2
#   Downloading asyncer-0.0.2-py3-none-any.whl (8.3 kB)
# Collecting fastapi~=0.87.0
#   Downloading fastapi-0.87.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 KB 3.1 MB/s eta 0:00:00
# Collecting pillow~=9.3.0
#   Downloading Pillow-9.3.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 42.4 MB/s eta 0:00:00
# Collecting pymatting~=1.1.8
#   Downloading PyMatting-1.1.8-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 KB 3.5 MB/s eta 0:00:00
# Collecting numpy~=1.23.5
#   Downloading numpy-1.23.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 36.7 MB/s eta 0:00:00
# Requirement already satisfied: click~=8.1.3 in /usr/local/lib/python3.9/dist-packages (from rembg[gpu]) (8.1.3)
# Collecting onnxruntime~=1.13.1
#   Downloading onnxruntime-1.13.1-cp39-cp39-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: imagehash~=4.3.1 in /usr/local/lib/python3.9/dist-packages (from rembg[gpu]) (4.3.1)
# Collecting onnxruntime-gpu~=1.13.1
#   Downloading onnxruntime_gpu-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 MB 9.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp~=3.8.1->rembg[gpu]) (2.0.12)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 4.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp~=3.8.1->rembg[gpu]) (22.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 3.8 MB/s eta 0:00:00
# Collecting anyio<4.0.0,>=3.4.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 5.5 MB/s eta 0:00:00
# Collecting starlette==0.21.0
#   Downloading starlette-0.21.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 KB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /usr/local/lib/python3.9/dist-packages (from fastapi~=0.87.0->rembg[gpu]) (1.10.6)
# Requirement already satisfied: typing-extensions>=3.10.0 in /usr/local/lib/python3.9/dist-packages (from starlette==0.21.0->fastapi~=0.87.0->rembg[gpu]) (4.5.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.9/dist-packages (from imagehash~=4.3.1->rembg[gpu]) (1.4.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.9/dist-packages (from onnxruntime~=1.13.1->rembg[gpu]) (23.3.3)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime~=1.13.1->rembg[gpu]) (1.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from onnxruntime~=1.13.1->rembg[gpu]) (23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.9/dist-packages (from onnxruntime~=1.13.1->rembg[gpu]) (3.19.6)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pooch~=1.6.0->rembg[gpu]) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from pooch~=1.6.0->rembg[gpu]) (2.27.1)
# Requirement already satisfied: numba!=0.49.0 in /usr/local/lib/python3.9/dist-packages (from pymatting~=1.1.8->rembg[gpu]) (0.56.4)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image~=0.19.3->rembg[gpu]) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image~=0.19.3->rembg[gpu]) (2023.3.15)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image~=0.19.3->rembg[gpu]) (3.0)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.9/dist-packages (from anyio<4.0.0,>=3.4.0->asyncer~=0.0.2->rembg[gpu]) (3.4)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba!=0.49.0->pymatting~=1.1.8->rembg[gpu]) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba!=0.49.0->pymatting~=1.1.8->rembg[gpu]) (67.6.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch~=1.6.0->rembg[gpu]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->pooch~=1.6.0->rembg[gpu]) (2022.12.7)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime~=1.13.1->rembg[gpu]) (1.3.0)
# Installing collected packages: filetype, watchdog, tqdm, sniffio, python-multipart, pillow, numpy, multidict, humanfriendly, h11, frozenlist, async-timeout, yarl, uvicorn, scipy, opencv-python-headless, coloredlogs, anyio, aiosignal, starlette, pymatting, onnxruntime-gpu, onnxruntime, asyncer, aiohttp, fastapi, rembg
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 anyio-3.6.2 async-timeout-4.0.2 asyncer-0.0.2 coloredlogs-15.0.1 fastapi-0.87.0 filetype-1.2.0 frozenlist-1.3.3 h11-0.14.0 humanfriendly-10.0 multidict-6.0.4 numpy-1.23.5 onnxruntime-1.13.1 onnxruntime-gpu-1.13.1 opencv-python-headless-4.6.0.66 pillow-9.3.0 pymatting-1.1.8 python-multipart-0.0.6 rembg-2.0.30 scipy-1.9.3 sniffio-1.3.0 starlette-0.21.0 tqdm-4.64.1 uvicorn-0.20.0 watchdog-2.1.9 yarl-1.8.2

# %%
pip install --ignore-installed Pillow==9.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Pillow==9.0.0
#   Downloading Pillow-9.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 32.3 MB/s eta 0:00:00
# Installing collected packages: Pillow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rembg 2.0.30 requires pillow~=9.3.0, but you have pillow 9.0.0 which is incompatible.
# Successfully installed Pillow-9.3.0

# %%
from rembg import remove
from PIL import Image
input_path = '/content/drive/MyDrive/testinput.jpg'
output_path = 'output.png'
input = Image.open(input_path)
output = remove(input)
output.save(output_path)
# Out:
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx' to file '/root/.u2net/u2net.onnx'.
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 90.4GB/s]

# %%
output
# Out:
# <PIL.Image.Image image mode=RGBA size=1365x768 at 0x7F393445E370>
